# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#Personal imports.
from pprint import pprint
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import Formatter

# %matplotlib inline

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=95.000, size=1600)
lngs = np.random.uniform(low=-181.000, high=181.000, size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lits for holding the query information and to keep track of the records and sets.
record = 1
Set = 1
city_df = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []

#Creates header of the data retrieval log. 
s = '-' * 30
print(f'Beginning Data Retrieval\n{s}')

#For each city in the list of randome cities .
for city in cities:
    
    #If the record is equal to 50 then reset record to 1 and add 1 to the set.
    if record == 50:
        Set += 1
        record = 1
    #if the record is less than 50 then try.
    try:
        #Query url for each city.
        query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=Imperial&q={city}"
        #Data in json format for each city.
        weather_data = requests.get(query_url).json()
        
        #Appends data to each of the empty lists created earlier.
        city_df.append(weather_data['name'])
        cloudiness.append(weather_data['clouds']['all'])
        country.append(weather_data['sys']['country'])
        date.append(pd.to_datetime(weather_data['dt'], unit = 's')) #Converts Unix data to datetime
        humidity.append(weather_data['main']['humidity'])
        lat.append(weather_data['coord']['lat'])
        lng.append(weather_data['coord']['lon'])
        maxTemp.append(weather_data['main']['temp_max'])
        windSpeed.append(weather_data['wind']['speed'])
        
        #Prints a log in the command line.
        print(f'Processing Record {record} of set {Set} | {city.title()}')
        
        #When eveything is done, adds a 1 to the record tally.
        record += 1
    
    #If data is not found for the desired city, then retur this message.
    except:
        print('City not found. Skipping...')
        
#End of the log.      
print(f'{s}\nData Retrieval Complete\n{s}')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of set 1 | Maldonado
# Processing Record 2 of set 1 | Hushitai
# Processing Record 3 of set 1 | Saldanha
# Processing Record 4 of set 1 | Tanabe
# Processing Record 5 of set 1 | Asha
# Processing Record 6 of set 1 | Ancud
# Processing Record 7 of set 1 | Aklavik
# Processing Record 8 of set 1 | Avera
# Processing Record 9 of set 1 | Mahebourg
# Processing Record 10 of set 1 | Bredasdorp
# Processing Record 11 of set 1 | Mataura
# Processing Record 12 of set 1 | Tasiilaq
# Processing Record 13 of set 1 | Qaanaaq
# Processing Record 14 of set 1 | Thompson
# Processing Record 15 of set 1 | Avarua
# Processing Record 16 of set 1 | Lorengau
# Processing Record 17 of set 1 | Ponta Do Sol
# Processing Record 18 of set 1 | Fairbanks
# Processing Record 19 of set 1 | Portland
# Processing Record 20 of set 1 | Hobart
# Processing Record 21 of set 1 | Kapaa
# Processing Record 22 of set 1 | Tabou
# Processing Record 23 of set 1 | Cape Town
# Processing Record 24 of set 1 | Bakhtiyarpur
# Processing Record 25 of set 1 | Rikitea
# Processing Record 26 of set 1 | Punta Arenas
# Processing Record 27 of set 1 | San Policarpo
# Processing Record 28 of set 1 | Norman Wells
# Processing Record 29 of set 1 | Roma
# Processing Record 30 of set 1 | Sao Miguel
# Processing Record 31 of set 1 | Port Alfred
# Processing Record 32 of set 1 | Chuy
# Processing Record 33 of set 1 | Atar
# Processing Record 34 of set 1 | Yumen
# Processing Record 35 of set 1 | Longyearbyen
# Processing Record 36 of set 1 | Deputatskiy
# Processing Record 37 of set 1 | Carnarvon
# Processing Record 38 of set 1 | Albany
# Processing Record 39 of set 1 | Port Elizabeth
# Processing Record 40 of set 1 | Kodinsk
# Processing Record 41 of set 1 | Narsaq
# Processing Record 42 of set 1 | Ushuaia
# Processing Record 43 of set 1 | Upernavik
# Processing Record 44 of set 1 | Busselton
# City not found. Skipping...
# Processing Record 45 of set 1 | Broken Hill
# City not found. Skipping...
# Processing Record 46 of set 1 | Barrow
# Processing Record 47 of set 1 | Whitehorse
# Processing Record 48 of set 1 | Manono
# Processing Record 49 of set 1 | Falmouth
# Processing Record 1 of set 2 | Sao Joao Da Barra
# Processing Record 2 of set 2 | Puerto Ayora
# Processing Record 3 of set 2 | Chokurdakh
# Processing Record 4 of set 2 | Jamestown
# Processing Record 5 of set 2 | Buchanan
# Processing Record 6 of set 2 | San Vicente
# Processing Record 7 of set 2 | Nikolskoye
# Processing Record 8 of set 2 | Buala
# City not found. Skipping...
# Processing Record 9 of set 2 | Bethel
# Processing Record 10 of set 2 | Manjacaze
# Processing Record 11 of set 2 | Le Vauclin
# Processing Record 12 of set 2 | Atuona
# Processing Record 13 of set 2 | Taltal
# Processing Record 14 of set 2 | Dikson
# Processing Record 15 of set 2 | Mayo
# City not found. Skipping...
# Processing Record 16 of set 2 | Yellowknife
# Processing Record 17 of set 2 | Penzance
# Processing Record 18 of set 2 | Butaritari
# Processing Record 19 of set 2 | Tuktoyaktuk
# Processing Record 20 of set 2 | Esperance
# City not found. Skipping...
# Processing Record 21 of set 2 | Goderich
# Processing Record 22 of set 2 | Kahului
# Processing Record 23 of set 2 | Hambantota
# City not found. Skipping...
# Processing Record 24 of set 2 | Saint Anthony
# Processing Record 25 of set 2 | High Prairie
# City not found. Skipping...
# Processing Record 26 of set 2 | Hilo
# Processing Record 27 of set 2 | Olafsvik
# Processing Record 28 of set 2 | Hermanus
# Processing Record 29 of set 2 | Zunyi
# Processing Record 30 of set 2 | Bilibino
# City not found. Skipping...
# Processing Record 31 of set 2 | Cabedelo
# Processing Record 32 of set 2 | Faya
# City not found. Skipping...
# Processing Record 33 of set 2 | Qasigiannguit
# Processing Record 34 of set 2 | Altamont
# Processing Record 35 of set 2 | Kiama
# Processing Record 36 of set 2 | Surgut
# Processing Record 37 of set 2 | Ribeira Grande
# Processing Record 38 of set 2 | Benguela
# Processing Record 39 of set 2 | Burnie
# Processing Record 40 of set 2 | Kruisfontein
# Processing Record 41 of set 2 | Gambela
# Processing Record 42 of set 2 | Kodiak
# City not found. Skipping...
# Processing Record 43 of set 2 | Muros
# Processing Record 44 of set 2 | Izhma
# Processing Record 45 of set 2 | Vaini
# Processing Record 46 of set 2 | Provideniya
# Processing Record 47 of set 2 | Wattegama
# Processing Record 48 of set 2 | Klyuchi
# Processing Record 49 of set 2 | East London
# Processing Record 1 of set 3 | Darien
# Processing Record 2 of set 3 | Sechura
# Processing Record 3 of set 3 | Pisco
# Processing Record 4 of set 3 | Baghdad
# Processing Record 5 of set 3 | Khatanga
# Processing Record 6 of set 3 | Sitka
# Processing Record 7 of set 3 | Udala
# Processing Record 8 of set 3 | Changying
# Processing Record 9 of set 3 | Mar Del Plata
# Processing Record 10 of set 3 | Hithadhoo
# Processing Record 11 of set 3 | Mount Isa
# Processing Record 12 of set 3 | Basmat
# City not found. Skipping...
# Processing Record 13 of set 3 | Tura
# Processing Record 14 of set 3 | Maryville
# Processing Record 15 of set 3 | Samarai
# Processing Record 16 of set 3 | Ilulissat
# Processing Record 17 of set 3 | Naze
# Processing Record 18 of set 3 | Montignoso
# Processing Record 19 of set 3 | Hasaki
# Processing Record 20 of set 3 | Cockburn Town
# Processing Record 21 of set 3 | Acapulco
# Processing Record 22 of set 3 | Bengkulu
# Processing Record 23 of set 3 | Kipushi
# Processing Record 24 of set 3 | Harper
# Processing Record 25 of set 3 | Faanui
# Processing Record 26 of set 3 | Erenhot
# Processing Record 27 of set 3 | Tigil
# Processing Record 28 of set 3 | Filadelfia
# Processing Record 29 of set 3 | Iqaluit
# Processing Record 30 of set 3 | Baoding
# Processing Record 31 of set 3 | Jasper
# Processing Record 32 of set 3 | Guhagar
# Processing Record 33 of set 3 | Saint George
# Processing Record 34 of set 3 | Torbay
# Processing Record 35 of set 3 | Saskylakh
# Processing Record 36 of set 3 | Bluff
# City not found. Skipping...
# Processing Record 37 of set 3 | Coihaique
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of set 3 | Vao
# City not found. Skipping...
# Processing Record 39 of set 3 | Beringovskiy
# City not found. Skipping...
# Processing Record 40 of set 3 | Arrifes
# Processing Record 41 of set 3 | Alofi
# Processing Record 42 of set 3 | Ambilobe
# City not found. Skipping...
# Processing Record 43 of set 3 | Sao Gabriel Da Cachoeira
# Processing Record 44 of set 3 | Mehamn
# Processing Record 45 of set 3 | Apastovo
# Processing Record 46 of set 3 | Caravelas
# Processing Record 47 of set 3 | Majene
# Processing Record 48 of set 3 | Chatellerault
# Processing Record 49 of set 3 | Kharp
# Processing Record 1 of set 4 | Tiksi
# Processing Record 2 of set 4 | Cherskiy
# Processing Record 3 of set 4 | Hovd
# Processing Record 4 of set 4 | Ojinaga
# Processing Record 5 of set 4 | New Norfolk
# Processing Record 6 of set 4 | Veinticinco De Mayo
# Processing Record 7 of set 4 | Anju
# Processing Record 8 of set 4 | Shimoda
# City not found. Skipping...
# Processing Record 9 of set 4 | Ekibastuz
# Processing Record 10 of set 4 | Lipari
# Processing Record 11 of set 4 | Tabas
# Processing Record 12 of set 4 | Sargur
# Processing Record 13 of set 4 | Havelock
# Processing Record 14 of set 4 | Codrington
# Processing Record 15 of set 4 | Tazovskiy
# City not found. Skipping...
# Processing Record 16 of set 4 | Klaksvik
# Processing Record 17 of set 4 | Sai Buri
# Processing Record 18 of set 4 | Georgetown
# Processing Record 19 of set 4 | Pevek
# Processing Record 20 of set 4 | Geraldton
# Processing Record 21 of set 4 | Koulamoutou
# Processing Record 22 of set 4 | Sakaiminato
# Processing Record 23 of set 4 | Changli
# Processing Record 24 of set 4 | Chandler
# Processing Record 25 of set 4 | Kushmurun
# Processing Record 26 of set 4 | Luanda
# Processing Record 27 of set 4 | Taoudenni
# Processing Record 28 of set 4 | Bowen
# Processing Record 29 of set 4 | Barentu
# Processing Record 30 of set 4 | Saint-Philippe
# Processing Record 31 of set 4 | Killybegs
# Processing Record 32 of set 4 | Talcahuano
# Processing Record 33 of set 4 | Savalou
# Processing Record 34 of set 4 | Ostrovnoy
# Processing Record 35 of set 4 | Mogadishu
# Processing Record 36 of set 4 | Vardo
# Processing Record 37 of set 4 | Manali
# Processing Record 38 of set 4 | Sinegorye
# Processing Record 39 of set 4 | Linxia
# Processing Record 40 of set 4 | Arraial Do Cabo
# Processing Record 41 of set 4 | Conakry
# Processing Record 42 of set 4 | Nome
# Processing Record 43 of set 4 | Kalagarh
# Processing Record 44 of set 4 | Bambous Virieux
# Processing Record 45 of set 4 | Vostok
# Processing Record 46 of set 4 | Katsuura
# Processing Record 47 of set 4 | Kazanka
# Processing Record 48 of set 4 | La Gomera
# Processing Record 49 of set 4 | Kaeo
# Processing Record 1 of set 5 | Tartagal
# Processing Record 2 of set 5 | Hervey Bay
# City not found. Skipping...
# Processing Record 3 of set 5 | Manokwari
# City not found. Skipping...
# Processing Record 4 of set 5 | Cidreira
# Processing Record 5 of set 5 | Catuday
# Processing Record 6 of set 5 | Kabinda
# Processing Record 7 of set 5 | Valdivia
# Processing Record 8 of set 5 | Anahuac
# Processing Record 9 of set 5 | Sola
# Processing Record 10 of set 5 | Paternion
# Processing Record 11 of set 5 | Lebu
# Processing Record 12 of set 5 | Guerrero Negro
# Processing Record 13 of set 5 | La Plata
# Processing Record 14 of set 5 | Trelew
# Processing Record 15 of set 5 | Castro
# Processing Record 16 of set 5 | Beysehir
# Processing Record 17 of set 5 | Dunedin
# Processing Record 18 of set 5 | Karratha
# Processing Record 19 of set 5 | Luganville
# Processing Record 20 of set 5 | Dolinsk
# Processing Record 21 of set 5 | Ixtapa
# Processing Record 22 of set 5 | Sirjan
# Processing Record 23 of set 5 | Coos Bay
# Processing Record 24 of set 5 | Tombouctou
# Processing Record 25 of set 5 | Mount Gambier
# City not found. Skipping...
# Processing Record 26 of set 5 | Omboue
# Processing Record 27 of set 5 | Port Said
# City not found. Skipping...
# Processing Record 28 of set 5 | San Cristobal
# City not found. Skipping...
# Processing Record 29 of set 5 | Batagay-Alyta
# Processing Record 30 of set 5 | Tibati
# Processing Record 31 of set 5 | Mangai
# Processing Record 32 of set 5 | Alvaraes
# Processing Record 33 of set 5 | Verkhnevilyuysk
# Processing Record 34 of set 5 | Padang
# Processing Record 35 of set 5 | Fortuna
# City not found. Skipping...
# Processing Record 36 of set 5 | San Quintin
# Processing Record 37 of set 5 | Charleston
# Processing Record 38 of set 5 | Sao Raimundo Nonato
# Processing Record 39 of set 5 | Mazamari
# Processing Record 40 of set 5 | Ischia
# Processing Record 41 of set 5 | Basco
# Processing Record 42 of set 5 | Petauke
# Processing Record 43 of set 5 | Kieta
# Processing Record 44 of set 5 | Lata
# City not found. Skipping...
# Processing Record 45 of set 5 | Yangambi
# Processing Record 46 of set 5 | Fort Walton Beach
# Processing Record 47 of set 5 | Gat
# Processing Record 48 of set 5 | Itarema
# Processing Record 49 of set 5 | Tyubuk
# Processing Record 1 of set 6 | Colares
# Processing Record 2 of set 6 | Baoqing
# City not found. Skipping...
# Processing Record 3 of set 6 | Nortelandia
# Processing Record 4 of set 6 | Te Anau
# Processing Record 5 of set 6 | Raga
# Processing Record 6 of set 6 | Am Timan
# Processing Record 7 of set 6 | Saint-Augustin
# Processing Record 8 of set 6 | Gravdal
# Processing Record 9 of set 6 | Teya
# Processing Record 10 of set 6 | Atmakur
# Processing Record 11 of set 6 | Guane
# Processing Record 12 of set 6 | Litovko
# Processing Record 13 of set 6 | Port Blair
# Processing Record 14 of set 6 | Srednekolymsk
# Processing Record 15 of set 6 | Mahajanga
# Processing Record 16 of set 6 | Kelvington
# City not found. Skipping...
# Processing Record 17 of set 6 | Talnakh
# Processing Record 18 of set 6 | Celestun
# Processing Record 19 of set 6 | Clyde River
# Processing Record 20 of set 6 | Wukari
# Processing Record 21 of set 6 | Pudozh
# City not found. Skipping...
# Processing Record 22 of set 6 | Maseru
# Processing Record 23 of set 6 | Gornoye Loo
# Processing Record 24 of set 6 | Saint-Pierre
# Processing Record 25 of set 6 | Krasnyy Luch
# Processing Record 26 of set 6 | Asau
# Processing Record 27 of set 6 | Mikhaylovsk
# Processing Record 28 of set 6 | Presidente Venceslau
# Processing Record 29 of set 6 | Bousso
# Processing Record 30 of set 6 | Nanortalik
# Processing Record 31 of set 6 | San Patricio
# Processing Record 32 of set 6 | Pustoshka
# Processing Record 33 of set 6 | Souillac
# Processing Record 34 of set 6 | Victoria
# Processing Record 35 of set 6 | Cabo San Lucas
# Processing Record 36 of set 6 | Fairhaven
# Processing Record 37 of set 6 | Loubomo
# Processing Record 38 of set 6 | Dundwaraganj
# Processing Record 39 of set 6 | Kulhudhuffushi
# Processing Record 40 of set 6 | Novopokrovka
# Processing Record 41 of set 6 | Nouakchott
# Processing Record 42 of set 6 | Charlestown
# Processing Record 43 of set 6 | Touros
# Processing Record 44 of set 6 | Puerto Escondido
# Processing Record 45 of set 6 | Yerbogachen
# Processing Record 46 of set 6 | Chebarkul
# Processing Record 47 of set 6 | Agadir
# Processing Record 48 of set 6 | Tuatapere
# Processing Record 49 of set 6 | Diamantino
# Processing Record 1 of set 7 | Laguna
# Processing Record 2 of set 7 | Belaya Gora
# Processing Record 3 of set 7 | Vanavara
# Processing Record 4 of set 7 | North Bend
# Processing Record 5 of set 7 | Bocas Del Toro
# Processing Record 6 of set 7 | Dingle
# Processing Record 7 of set 7 | Salalah
# Processing Record 8 of set 7 | De Aar
# Processing Record 9 of set 7 | Coquimbo
# Processing Record 10 of set 7 | Zhigansk
# Processing Record 11 of set 7 | Leningradskiy
# Processing Record 12 of set 7 | Azovo
# Processing Record 13 of set 7 | Khani
# Processing Record 14 of set 7 | Kudahuvadhoo
# Processing Record 15 of set 7 | Bella Union
# Processing Record 16 of set 7 | Baykit
# Processing Record 17 of set 7 | Hurghada
# Processing Record 18 of set 7 | Raudeberg
# Processing Record 19 of set 7 | Constitucion
# Processing Record 20 of set 7 | Saint-Joseph
# City not found. Skipping...
# Processing Record 21 of set 7 | Bambanglipuro
# Processing Record 22 of set 7 | Jaitaran
# Processing Record 23 of set 7 | Vigrestad
# City not found. Skipping...
# Processing Record 24 of set 7 | Gueret
# Processing Record 25 of set 7 | Nouadhibou
# Processing Record 26 of set 7 | Usinsk
# Processing Record 27 of set 7 | General Pico
# City not found. Skipping...
# Processing Record 28 of set 7 | Pacific Grove
# Processing Record 29 of set 7 | Yar-Sale
# Processing Record 30 of set 7 | Pathein
# City not found. Skipping...
# Processing Record 31 of set 7 | San Bernardino
# Processing Record 32 of set 7 | Shitkino
# Processing Record 33 of set 7 | Alta Floresta
# Processing Record 34 of set 7 | Quatre Cocos
# Processing Record 35 of set 7 | San Andres
# Processing Record 36 of set 7 | Saint-Leu
# Processing Record 37 of set 7 | High Level
# Processing Record 38 of set 7 | Shenjiamen
# Processing Record 39 of set 7 | Manati
# Processing Record 40 of set 7 | Severo-Yeniseyskiy
# Processing Record 41 of set 7 | Hobyo
# Processing Record 42 of set 7 | La Palma
# Processing Record 43 of set 7 | Farafangana
# Processing Record 44 of set 7 | Coolum Beach
# City not found. Skipping...
# Processing Record 45 of set 7 | Araouane
# Processing Record 46 of set 7 | Nizwa
# Processing Record 47 of set 7 | Cayenne
# Processing Record 48 of set 7 | Poum
# Processing Record 49 of set 7 | Amahai
# Processing Record 1 of set 8 | Tornio
# Processing Record 2 of set 8 | San Carlos De Bariloche
# Processing Record 3 of set 8 | Afua
# City not found. Skipping...
# Processing Record 4 of set 8 | Ucluelet
# Processing Record 5 of set 8 | Abeche
# Processing Record 6 of set 8 | Korla
# Processing Record 7 of set 8 | San Ramon De La Nueva Oran
# Processing Record 8 of set 8 | Dhadar
# Processing Record 9 of set 8 | Dudinka
# Processing Record 10 of set 8 | Severo-Kurilsk
# Processing Record 11 of set 8 | Escanaba
# Processing Record 12 of set 8 | Barinas
# Processing Record 13 of set 8 | Gubkinskiy
# Processing Record 14 of set 8 | Nanjing
# Processing Record 15 of set 8 | Acarau
# City not found. Skipping...
# Processing Record 16 of set 8 | Sao Filipe
# Processing Record 17 of set 8 | Marand
# City not found. Skipping...
# Processing Record 18 of set 8 | Beecher
# Processing Record 19 of set 8 | Kupang
# Processing Record 20 of set 8 | Kuching
# Processing Record 21 of set 8 | Airai
# Processing Record 22 of set 8 | La Asuncion
# Processing Record 23 of set 8 | Luderitz
# Processing Record 24 of set 8 | Chuguyevka
# Processing Record 25 of set 8 | Waingapu
# Processing Record 26 of set 8 | Aljezur
# Processing Record 27 of set 8 | Hokitika
# City not found. Skipping...
# Processing Record 28 of set 8 | Yulara
# Processing Record 29 of set 8 | Grand Gaube
# Processing Record 30 of set 8 | Banda Aceh
# Processing Record 31 of set 8 | Mgandu
# Processing Record 32 of set 8 | Salinopolis
# Processing Record 33 of set 8 | Antalaha
# Processing Record 34 of set 8 | Sobolevo
# Processing Record 35 of set 8 | Upata
# Processing Record 36 of set 8 | Bandarbeyla
# Processing Record 37 of set 8 | Santa Maria
# Processing Record 38 of set 8 | Gushikawa
# Processing Record 39 of set 8 | Asfi
# Processing Record 40 of set 8 | Voznesenye
# Processing Record 41 of set 8 | Nanfeng
# Processing Record 42 of set 8 | Kavaratti
# Processing Record 43 of set 8 | Pontes E Lacerda
# Processing Record 44 of set 8 | Ukiah
# Processing Record 45 of set 8 | Terekli-Mekteb
# Processing Record 46 of set 8 | Abonnema
# Processing Record 47 of set 8 | Guangshui
# Processing Record 48 of set 8 | Pochutla
# City not found. Skipping...
# Processing Record 49 of set 8 | Dauphin
# Processing Record 1 of set 9 | Margate
# Processing Record 2 of set 9 | Inirida
# Processing Record 3 of set 9 | Semiletka
# Processing Record 4 of set 9 | Huanren
# Processing Record 5 of set 9 | Seoni
# Processing Record 6 of set 9 | Ust-Ishim
# Processing Record 7 of set 9 | Komsomolskiy
# Processing Record 8 of set 9 | Erdenet
# Processing Record 9 of set 9 | Batemans Bay
# Processing Record 10 of set 9 | Qandala
# Processing Record 11 of set 9 | Zalantun
# Processing Record 12 of set 9 | Oshnaviyeh
# Processing Record 13 of set 9 | Kavieng
# Processing Record 14 of set 9 | Raton
# Processing Record 15 of set 9 | Suamico
# Processing Record 16 of set 9 | Angoche
# Processing Record 17 of set 9 | Lodja
# Processing Record 18 of set 9 | Olinda
# Processing Record 19 of set 9 | Havre-Saint-Pierre
# Processing Record 20 of set 9 | Tadine
# Processing Record 21 of set 9 | Izumo
# Processing Record 22 of set 9 | Birjand
# City not found. Skipping...
# Processing Record 23 of set 9 | Ozernovskiy
# Processing Record 24 of set 9 | Bezhanitsy
# Processing Record 25 of set 9 | Oranjestad
# Processing Record 26 of set 9 | Guarapari
# Processing Record 27 of set 9 | Kasongo-Lunda
# Processing Record 28 of set 9 | Berdigestyakh
# Processing Record 29 of set 9 | Belokurikha
# Processing Record 30 of set 9 | Mananjary
# Processing Record 31 of set 9 | Krasnokamensk
# Processing Record 32 of set 9 | Methoni
# Processing Record 33 of set 9 | Otjimbingwe
# Processing Record 34 of set 9 | Rameswaram
# Processing Record 35 of set 9 | Brigantine
# Processing Record 36 of set 9 | Yei
# Processing Record 37 of set 9 | Simao
# Processing Record 38 of set 9 | Caibarien
# Processing Record 39 of set 9 | Samfya
# City not found. Skipping...
# Processing Record 40 of set 9 | Bridlington
# Processing Record 41 of set 9 | Kondinskoye
# Processing Record 42 of set 9 | Tsiroanomandidy
# City not found. Skipping...
# Processing Record 43 of set 9 | Lompoc
# Processing Record 44 of set 9 | Bathsheba
# Processing Record 45 of set 9 | Nelson Bay
# Processing Record 46 of set 9 | Odweyne
# City not found. Skipping...
# Processing Record 47 of set 9 | Bloemfontein
# Processing Record 48 of set 9 | Swan Hill
# Processing Record 49 of set 9 | Van
# Processing Record 1 of set 10 | Lasa
# Processing Record 2 of set 10 | Rundu
# Processing Record 3 of set 10 | Awbari
# Processing Record 4 of set 10 | College
# Processing Record 5 of set 10 | Senneterre
# Processing Record 6 of set 10 | Zyryanskoye
# Processing Record 7 of set 10 | Northam
# Processing Record 8 of set 10 | Farmington
# Processing Record 9 of set 10 | Hofn
# Processing Record 10 of set 10 | Alcantara
# Processing Record 11 of set 10 | Tautira
# Processing Record 12 of set 10 | Denpasar
# Processing Record 13 of set 10 | Manggar
# Processing Record 14 of set 10 | Jamame
# Processing Record 15 of set 10 | Borba
# Processing Record 16 of set 10 | Hualmay
# Processing Record 17 of set 10 | Port Macquarie
# City not found. Skipping...
# Processing Record 18 of set 10 | Jining
# Processing Record 19 of set 10 | Sur
# Processing Record 20 of set 10 | Tuy Hoa
# Processing Record 21 of set 10 | Berlevag
# Processing Record 22 of set 10 | Ust-Maya
# Processing Record 23 of set 10 | Eyl
# Processing Record 24 of set 10 | Sanary-Sur-Mer
# Processing Record 25 of set 10 | Hohhot
# Processing Record 26 of set 10 | Storebo
# Processing Record 27 of set 10 | Narsipatnam
# Processing Record 28 of set 10 | Sorland
# Processing Record 29 of set 10 | Roccastrada
# Processing Record 30 of set 10 | Juan Lacaze
# Processing Record 31 of set 10 | Corinto
# Processing Record 32 of set 10 | Taksimo
# Processing Record 33 of set 10 | Luena
# Processing Record 34 of set 10 | Yantongshan
# Processing Record 35 of set 10 | Petropavlovka
# Processing Record 36 of set 10 | Russell
# Processing Record 37 of set 10 | Timmins
# City not found. Skipping...
# Processing Record 38 of set 10 | Aden
# Processing Record 39 of set 10 | Barro
# Processing Record 40 of set 10 | Rodez
# Processing Record 41 of set 10 | Coahuayana
# Processing Record 42 of set 10 | Dicabisagan
# Processing Record 43 of set 10 | Rio Grande
# Processing Record 44 of set 10 | Batagay
# Processing Record 45 of set 10 | Chara
# Processing Record 46 of set 10 | Lander
# Processing Record 47 of set 10 | Launceston
# Processing Record 48 of set 10 | Boda
# Processing Record 49 of set 10 | Kidal
# Processing Record 1 of set 11 | Aykhal
# Processing Record 2 of set 11 | Suhut
# Processing Record 3 of set 11 | San Isidro
# Processing Record 4 of set 11 | Broome
# Processing Record 5 of set 11 | Kropotkin
# Processing Record 6 of set 11 | Marsaxlokk
# Processing Record 7 of set 11 | Tilichiki
# Processing Record 8 of set 11 | Albanel
# Processing Record 9 of set 11 | Tortona
# City not found. Skipping...
# Processing Record 10 of set 11 | Hanmer Springs
# Processing Record 11 of set 11 | Palauig
# Processing Record 12 of set 11 | Westport
# Processing Record 13 of set 11 | Baracoa
# Processing Record 14 of set 11 | Bossier City
# Processing Record 15 of set 11 | Solnechnyy
# Processing Record 16 of set 11 | Halifax
# Processing Record 17 of set 11 | Biu
# Processing Record 18 of set 11 | Egvekinot
# Processing Record 19 of set 11 | Brandon
# Processing Record 20 of set 11 | Juneau
# Processing Record 21 of set 11 | Port Hawkesbury
# Processing Record 22 of set 11 | Kaitangata
# Processing Record 23 of set 11 | Lamu
# Processing Record 24 of set 11 | Belmonte
# City not found. Skipping...
# Processing Record 25 of set 11 | Ust-Kuyga
# Processing Record 26 of set 11 | Polunochnoye
# Processing Record 27 of set 11 | Lingao
# Processing Record 28 of set 11 | Chambersburg
# Processing Record 29 of set 11 | Nantucket
# Processing Record 30 of set 11 | Lavrentiya
# Processing Record 31 of set 11 | La Tuque
# Processing Record 32 of set 11 | Vredefort
# Processing Record 33 of set 11 | Port Hardy
# Processing Record 34 of set 11 | Waddan
# Processing Record 35 of set 11 | Oshikango
# Processing Record 36 of set 11 | Mitsamiouli
# Processing Record 37 of set 11 | Lodingen
# Processing Record 38 of set 11 | Panzhihua
# Processing Record 39 of set 11 | Barkhan
# Processing Record 40 of set 11 | Asyut
# Processing Record 41 of set 11 | Qui Nhon
# Processing Record 42 of set 11 | Vila Franca Do Campo
# Processing Record 43 of set 11 | Hamilton
# Processing Record 44 of set 11 | Maniitsoq
# Processing Record 45 of set 11 | Remedios
# Processing Record 46 of set 11 | Shache
# Processing Record 47 of set 11 | Pietarsaari
# Processing Record 48 of set 11 | Beaverlodge
# Processing Record 49 of set 11 | Nuuk
# Processing Record 1 of set 12 | Weligama
# Processing Record 2 of set 12 | Prado
# Processing Record 3 of set 12 | Grand Island
# Processing Record 4 of set 12 | Pundaguitan
# Processing Record 5 of set 12 | Buin
# Processing Record 6 of set 12 | Batangafo
# Processing Record 7 of set 12 | Clyde
# Processing Record 8 of set 12 | La Ronge
# Processing Record 9 of set 12 | Chernigovka
# Processing Record 10 of set 12 | Banjar
# Processing Record 11 of set 12 | Swellendam
# Processing Record 12 of set 12 | Achacachi
# City not found. Skipping...
# Processing Record 13 of set 12 | Hami
# Processing Record 14 of set 12 | Santa Isabel Do Rio Negro
# Processing Record 15 of set 12 | Paita
# Processing Record 16 of set 12 | Masvingo
# Processing Record 17 of set 12 | Safaga
# Processing Record 18 of set 12 | Illela
# Processing Record 19 of set 12 | Grand Forks
# Processing Record 20 of set 12 | Nhulunbuy
# Processing Record 21 of set 12 | Bend
# Processing Record 22 of set 12 | Kaposvar
# Processing Record 23 of set 12 | Necochea
# Processing Record 24 of set 12 | San Luis
# Processing Record 25 of set 12 | Santa Lucia
# Processing Record 26 of set 12 | Anori
# Processing Record 27 of set 12 | Muriti
# Processing Record 28 of set 12 | Edd
# Processing Record 29 of set 12 | Los Llanos De Aridane
# Processing Record 30 of set 12 | Ilhabela
# Processing Record 31 of set 12 | Baiyin
# Processing Record 32 of set 12 | Rafai
# City not found. Skipping...
# Processing Record 33 of set 12 | Otane
# Processing Record 34 of set 12 | Aguas Formosas
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Dictionary to store all the lists.
city_dict = {
    'City' : city_df,
    'Cloudiness' : cloudiness,
    'Country' : country,
    'Date' : date,
    'Humidity' : humidity,
    'Lat' : lat,
    'Lng' : lng,
    'Max Temp' : maxTemp,
    'Wind Speed' : windSpeed
}

#Creates DataFrame from the dictionary.
weatherPy_df = pd.DataFrame(city_dict)

#Check for row total.
weatherPy_df.count()

#Check for data type. 
weatherPy_df.dtypes
# Out:
# City          573
# Cloudiness    573
# Country       573
# Date          573
# Humidity      573
# Lat           573
# Lng           573
# Max Temp      573
# Wind Speed    573
# dtype: int64

# %%
#Format datetime to show only year, month and day.
weatherPy_df['Date'] = weatherPy_df['Date'].dt.strftime('%d-%m-%Y')  

weatherPy_df.head()
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 0  Departamento de Maldonado          90      UY  18-06-2020        93 -34.67
# 1                   Hushitai           0      CN  18-06-2020        72  41.93
# 2                   Saldanha           0      ZA  18-06-2020        54 -33.01
# 3                     Tanabe         100      JP  18-06-2020        97  33.73
# 4                       Asha           0      RU  18-06-2020        76  55.00
#
#       Lng  Max Temp  Wind Speed
# 0  -54.92     57.99       14.99
# 1  123.51     64.40        4.47
# 2   17.94     57.20        4.70
# 3  135.37     66.99       11.88
# 4   57.27     44.02        4.41

# %%
#Csv output.
weatherPy_df.to_csv(output_data_file, index = False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Takes the data of our query. 
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (20,20))
fig.subplots_adjust(top=0.95) #Controls the space between the title and the figure.

#Title of the plot with the date.
fig.suptitle(f'Weather Analysis {date}', fontsize = 30)

#Plot 1
ax1.scatter(weatherPy_df['Lat'],
            weatherPy_df['Max Temp'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax1.set_ylabel('Max Temperature' , fontsize = 15)
ax1.set_xlabel('Latitude' , fontsize = 15)
ax1.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax1.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}F'.format(y))) #Formats y axis 
ax1.grid()

#Plot 2
ax2.scatter(weatherPy_df['Lat'],
            weatherPy_df['Humidity'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax2.set_ylabel('Humidity' , fontsize = 15)
ax2.set_xlabel('Latitude' , fontsize = 15)
ax2.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax2.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y))) #Formats y axis 
ax2.grid()

#Plot 3
ax3.scatter(weatherPy_df['Lat'],
            weatherPy_df['Cloudiness'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax3.set_ylabel('Cloudiness' , fontsize = 15)
ax3.set_xlabel('Latitude' , fontsize = 15)
ax3.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax3.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax3.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f}%'.format(y))) #Formats y axis 
ax3.grid()

#Plot 4
ax4.scatter(weatherPy_df['Lat'],
            weatherPy_df['Wind Speed'],
           facecolors = 'lightskyblue',
           edgecolors = 'black')
ax4.set_ylabel('Wind Speed' , fontsize = 15)
ax4.set_xlabel('Latitude' , fontsize = 15)
ax4.tick_params(axis='y',
                which='major',
                labelsize = 20)
ax4.tick_params(axis='x',
                which='major',
                labelsize = 15)
ax4.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0f} mph'.format(y))) #Formats y axis 
ax4.grid()

plt.show()

#Saves the plots.
fig.savefig("../output_data/latitudePLots.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = weatherPy_df[weatherPy_df["Lat"]>=0]
south_df = weatherPy_df[weatherPy_df["Lat"]<0]

#List of the paramters used to compare against latitude.
comparison = ['Max Temp', 'Humidity', 'Cloudiness','Wind Speed']

# %%
#Data distribution.
NorthernPct = len(north_df) / len(weatherPy_df) *100

NorthernPct

#Data distribution.
SouthernPct = len(south_df) / len(weatherPy_df) * 100

SouthernPct
# Out:
# 32.11169284467714

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Date of the query.
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, axs = plt.subplots(4, 1, figsize=(40,30))
cols_level = [f'ax_{i}' for i in range(len(axs.flat))] #1-D iterator to iterate over the array axs.

#Title
fig.suptitle(f'Northern Hemisphere Weather Analysis {date}', fontsize = 30)
fig.subplots_adjust(top=0.95) #Controls the space between the title and the plots.

#For loop to create plots. 
for i, ax in enumerate(axs.flat):
    
    #Data for the x and y
    x_values = north_df['Lat']
    y_values = north_df[comparison[i]]
    
    #Linear regression formula.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    #Line equation text and correlation factor.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + "\nThe r-squared is: " + str(round(rvalue,4))

    #Scatter plot. 
    ax.scatter(x_values,
               y_values,
               facecolors = 'lightskyblue',
               edgecolors = 'black')

    #Line plot - by plotting points of x values long the regressvalues. 
    ax.plot(x_values,regress_values,"r-")
    ax.annotate(line_eq,
             (0,-8), #location of the line_eq
             fontsize = 15,
             color = "red")

    #label for x and y axis.
    ax.set_xlabel('Latitude',fontsize = 15)
    ax.set_ylabel(comparison[i],fontsize = 25)
     
    #lim of y
    ax.set_ylim(-10,north_df[comparison[i]].max()+5)
    
    #Creates grid for each plot.
    ax.grid()
    
    #Selects the format for y based on the plot.
    if comparison[i] == 'Max Temp':
        formatAxis = '{:.0f}F'
        
    elif comparison[i] == 'Wind Speed':
        formatAxis = '{:.0f} mph'
        
    else:
        formatAxis = '{:.0f}%'
    
    #Applies the format to the y axis.
    ax.set_yticklabels([formatAxis.format(int(x)) for x in ax.get_yticks().tolist()])
    
    #Controls the size of the x and y ticks.
    ax.tick_params(axis='y',
                which='major',
                labelsize = 20)
    ax.tick_params(axis='x',
                which='major',
                labelsize = 13)

plt.show()

#Saves the plot. 
fig.savefig("../output_data/NorthernPLots.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Date
date = weatherPy_df.loc[0,'Date']

#Creates a figure with 4 plots.
fig, axs = plt.subplots(4, 1, figsize=(40,30))
cols_level = [f'ax_{i}' for i in range(len(axs.flat))]

#Title
fig.suptitle(f'Southern Hemisphere Weather Analysis {date}', fontsize = 30)
fig.subplots_adjust(top=0.95)

#For loop to create plots. 
for i, ax in enumerate(axs.flat):
    
     #Data for the x and y
    x_values = south_df['Lat']
    y_values = south_df[comparison[i]]
    
    #Linear regression formula.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    #Line equation text.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + "\nThe r-squared is: " + str(round(rvalue,4))

    #Scatter plot. 
    ax.scatter(x_values,
               y_values,
               facecolors = 'lightskyblue',
               edgecolors = 'black')

    #Line plot - by plotting points of x values long the regressvalues. 
    ax.plot(x_values,regress_values,"r-")
    ax.annotate(line_eq,
             (-50,-8),
             fontsize = 15,
             color = "red")
    #label for x and y axis.
    ax.set_xlabel('Latitude',fontsize = 15)
    ax.set_ylabel(comparison[i],fontsize = 25)
    
    #lim of y
    ax.set_ylim(-10,north_df[comparison[i]].max()+5)
    
    #Grid for each plot.
    ax.grid()
    
    #Selects the format for y based on the plot.
    if comparison[i] == 'Max Temp':
        formatAxis = '{:.0f}F'
        
    elif comparison[i] == 'Wind Speed':
        formatAxis = '{:.0f} mph'
        
    else:
        formatAxis = '{:.0f}%'
    
    #Applies the format to the y axis.
    ax.set_yticklabels([formatAxis.format(int(x)) for x in ax.get_yticks().tolist()])
    
    #Controls the size of the x and y ticks.
    ax.tick_params(axis='y',
                which='major',
                labelsize = 20)
    ax.tick_params(axis='x',
                which='major',
                labelsize = 13)

plt.show()

#Saves the plot.
fig.savefig("../output_data/SouthernPLots.png")
